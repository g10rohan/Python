# %%
Every day morning and evening milk is brought from 'n' farms to a milk
booth for sales. Given the amount of milk from 'n' farms, Write the
python code to compute total quantity of milk in the booth.
For example, if milk comes from 3 farms in quantities 2 litres 300ml, 3
litres 700ml and 4 litres 600ml then the total quantity of milk in booth is
10litre 600ml.
Input Format
First input is number of farms ‘n’
Next 'n' input is the amount of milk from 'n' farms
Output Format
Total quantity of milk in booth
Boundary Condition:
All input > 0

# %%
n=int(input("Enter numbers of farm"))
milk=0
milk1=0
if n>0:
  for i in range(0,n):
    l=int(input("Enter amount of milk in litre:-"))
    m=int(input("Enter amount of milk in ml:-"))
    if(l<0 or m<0):
      print("The values are less than zero")
      break;
    milk+=l
    milk1=m

milk+=milk1//1000
milk1=milk1%1000
print("The Total Milk :-",milk,"Litres",milk1,"ml")
# Out:
# Enter numbers of farm2
# Enter amount of milk in litre:-2
# Enter amount of milk in ml:-100
# Enter amount of milk in litre:-5
# Enter amount of milk in ml:-600
# The Total Milk :- 7 Litres 600 ml

# %% [markdown]
# Write the python code to simulate the working of an AND gate. AND
# gate takes two bits as input and output a bit as shown in the following
# table. Check for validity of input and print 'Invalid input' when user
# gives out of boundary values.
# Input Format:
# Read input for ‘X’ as,
# 0
# 0
# 1
# 1
# Read input for ‘Y’ as,
# 0
# 1
# 0
# 1
# Output Format:
# Print output as,
# 0
# 0
# 0
# 1
# Boundary Condition:
# X,Y should be either 0 or 1

# %%
X = []
for i in range(4):
  A = int(input("Enter input for X"))
  if A==1 or A==0:
    X.append(A)
  else:
    print("enter correct input")
    A = int(input("Enter input for X"))
    X.append(A)
Y = []
for i in range(4):
  B = int(input("Enter input for Y"))
  if B==1 or B==0:
    Y.append(B)
  else:
    print("enter correct input")
    B = int(input("Enter input for Y"))
    Y.append(B)
Z = []
for i in range(4):
  if X[i]==0 and Y[i]==0:
    Z.append(0)
  elif X[i]==1 and Y[i]==1:
    Z.append(1)
  else:
    Z.append(0)
print(Z)
# Out:
# Enter input for X0
# Enter input for X0
# Enter input for X1
# Enter input for X1
# Enter input for Y0
# Enter input for Y1
# Enter input for Y0
# Enter input for Y1
# [0, 0, 0, 1]

# %% [markdown]
# A health drink company, gives a festival offer to its retail customers.
# The health drink is packed in 1 kg pack. For every 5 one kg pack
# purchased, one 1kg pack will be free. (i.e. buy 5 get 1 free). Given the
# number of health drink packets purchased, develop python code to
# determine the total number of packets that the customer will get
# Example: If one small retail shop owner buys 125 one kg health drink
# pack, he will get 150 one kg packs.
# Explanation : Because for the 125 packs he purchased, he gets 25
# packs free.
# Input format:
# Number of health drink packets purchased
# Output format:
# Number of packets delivered
# Boundary conditions :
# 0< no. of health drink packs <= 500

# %%
quantity=int(input("Enter the Number of Health Drinks Packets Retailer Bought:-"))
free=(quantity//5)
total=free+quantity
if total>0 and total<=500:
  print("The Retailer Bought",quantity,"Health Drinks Packets and got",free,"Health Drinks Packets for Free and in total",total,"Health Drinks Packets")
else:
  print("Boundary Value Exceeded")
# Out:
# Enter the Number of Health Drinks Packets Retailer Bought:-125
# The Retailer Bought 125 Health Drinks Packets and got 25 Health Drinks Packets for Free and in total 150 Health Drinks Packets

# %% [markdown]
# Develop the python code to check whether the given number is an
# Armstrong number of three digits or not. A number is said to be
# Armstrong, if the sum of the cube of the digits in a three digit number
# is equal to that number. Check for boundary conditions, if the value
# entered is outside boundary conditions then enter 'Invalid input'
# Input Format:
# A number 'n'
# Output Format:
# Print ‘Armstrong’ or ‘ Not Armstrong ‘
# Boundary Conditions:
# n>=100 and <=999

# %%
num = int(input("Enter a number: "))
sum = 0
temp = num
if num>=100 and num<=999:
  while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10
  if num == sum:
    print(num,"is an Armstrong number")
  else:
    print(num,"is not an Armstrong number")
else:
  print(" Value Not within Boundary Value")
# Out:
# Enter a number: 153
# 153 is an Armstrong number

# %% [markdown]
# Given ‘n’, the number of rows, design an algorithm and write a Python
# code to draw a pattern. If n is ‘5’, the pattern looks as shown below:
# **
# ****
# ******
# ********
# **********
# Precode
# Test Cases Input 3
# Test Cases Expected Output
# **
# ****
# ******
# Test Cases Input 5
# Test Cases Expected Output
# **
# ****
# ******
# ********
# **********
# Test Cases Input 2
# Test Cases Expected Output
# **
# ****
# Test Cases Input 4
# Test Cases Expected Output
# **
# ****
# ******
# ********

# %%
n=int(input("Enter the Number of rows"))
for i in range(1,n+1):
  for j in range(0,i):
    print("**",end='')
  print('')
# Out:
# Enter the Number of rows6
# **
# ****
# ******
# ********
# **********
# ************

# %%
X = int(input("Enter the number"))
Y = int(input("Enter the number"))
A = []
B = []
coprime = 0
not_coprime = 0
for i in range(1,X+1):
  if X%i==0:
    A.append(i)
for j in range(1,Y+1):
  if Y%j==0:
    B.append(j)
if len(A)>len(B):
  for i in range(1,len(B)):
    for j in range(1,len(A)):
      if B[i]!=A[j]:
        coprime += 1
      else:
        not_coprime += 1
else:
  for i in range(1,len(A)):
    for j in range(1,len(B)):
      if A[i]!=B[i]:
        coprime += 1
      else:
        not_coprime += 1
if not_coprime>0:
  print("not coprime")
else:
  print("coprime")
# Out:
# Enter the number25
# Enter the number12
# coprime
